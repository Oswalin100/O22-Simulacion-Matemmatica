# %% [markdown]
# # Presentación Personal

# %% [markdown]
# ## Oswald Aceves Diaz

# %% [markdown]
# *Estudio ingeniería en **nanotecnología**, actualmente estoy cursando el quinto semestre, pero tengo algunas materias
# atrasadas.*
#
# Lo que me gusta hacer en mi tiempo libre es:
# - Jugar basquetbol
# - Salir a fiestas
# - Escuchar música
# Mis tres comidas favoritas son:
# 1. Pulpo
# 2. Pollo agridulce
# 3. Salmón
#
# $ Nanomedicina $
#
# Un tema o especialidad que me llama mucho la atención es la rama de la nanomedicina contra el cáncer, en
# la cual diseñan sistemas y estructuras que permiten enviar fármacos a domicilio hasta las células tumorales y gracias a la forma
# de la cápsula que contiene el medicamento atacan exclusivamente a las células malignas, es decir que tienen como una ranura
# por asi decirlo que encaja sólo con ellas siendo únicamente funcionales o compatibles sólo con las que se quieren destruir

# %% [markdown]
# ![] ![image-2.png](attachment:image-2.png)
